# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("output.csv")
df = df.reset_index(drop = False)
df.head()
# Out:
#    index  action    acc
# 0      0       0  -8.24
# 1      1       1 -14.22
# 2      2       0  -2.94
# 3      3       1 -15.30
# 4      4       0  -5.01

# %%
df0 = df[df['action'] == 0]
df0 = df0.reset_index(drop=True)
df0.head(10)
# Out:
#    index  action   acc
# 0      0       0 -8.24
# 1      2       0 -2.94
# 2      4       0 -5.01
# 3      6       0 -3.95
# 4      8       0 -5.36
# 5     10       0 -4.32
# 6     12       0 -5.87
# 7     14       0 -5.55
# 8     16       0 -6.55
# 9     18       0 -7.29

# %%
df1 = df[df['action'] == 1]
df1 = df1.reset_index(drop=True)
df1.head(10)
# Out:
#    index  action    acc
# 0      1       1 -14.22
# 1      3       1 -15.30
# 2      5       1 -24.66
# 3      7       1 -29.84
# 4      9       1 -19.93
# 5     11       1 -14.13
# 6     13       1 -13.86
# 7     15       1 -19.72
# 8     17       1 -12.30
# 9     19       1 -34.69

# %%
df2 = df[df['action'] == 2]
df2 = df2.reset_index(drop=True)
df2.head(10)
# Out:
#    index  action    acc
# 0    201       2 -33.23
# 1    203       2 -23.73
# 2    205       2 -29.64
# 3    207       2 -26.16
# 4    209       2 -25.37
# 5    211       2 -26.71
# 6    213       2 -37.86
# 7    215       2 -35.80
# 8    217       2 -94.89
# 9    219       2 -57.50

# %%
df3 = df[df['action'] == 3]
df3 = df3.reset_index(drop=True)
df3.head(10)
# Out:
#    index  action    acc
# 0    401       3 -21.54
# 1    403       3 -20.69
# 2    405       3 -18.67
# 3    407       3  -9.94
# 4    409       3 -13.73
# 5    411       3 -12.12
# 6    413       3  -7.57
# 7    415       3 -14.47
# 8    417       3  -8.96
# 9    419       3 -11.01

# %%
df4 = df[df['action'] == 4]
df4 = df4.reset_index(drop=True)
df4.head(10)
# Out:
#    index  action    acc
# 0    601       4  -9.96
# 1    603       4  -9.48
# 2    605       4  -9.52
# 3    607       4 -14.13
# 4    609       4  -7.63
# 5    611       4 -10.68
# 6    613       4 -14.21
# 7    615       4  -8.87
# 8    617       4  -8.36
# 9    619       4  -6.54

# %%
fig = plt.figure(figsize = (15,5))
ax1 = fig.add_subplot(111)
# plt.plot(df0['index'], df0['acc'], s=10, c='r', marker="s", label = '0')
# plt.plot(df1['index'], df1['acc'], s=10, c='b', marker="s", label = '1')
# plt.plot(df2['index'], df2['acc'], s=10, c='g', marker="s", label = '2')
# plt.plot(df3['index'], df3['acc'], s=10, c='y', marker="s", label = '3')
# plt.plot(df4['index'], df4['acc'], s=10, c='black', marker="s", label = '4')
plt.plot(df0['index'], df0['acc'], c='r', label = '0')
plt.plot(df1['index'], df1['acc'], c='b', label = '1')
plt.plot(df2['index'], df2['acc'], c='g', label = '2')
plt.plot(df3['index'], df3['acc'], c='y', label = '3')
plt.plot(df4['index'], df4['acc'], c='black', label = '4')
plt.legend(loc='upper left')
# plt.plot()
plt.show()
